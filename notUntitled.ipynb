# %%
import pandas as pd

# %%
cov = pd.read_csv('covid19.csv')

# %%
type(cov)
#dataframe <-> dict
# Out:
# pandas.core.frame.DataFrame

# %%
cov.tail(5)
# Out:
#        案例     新聞稿發布日期 性別  年齡  國籍     區域  來源           旅遊史 入境臺灣日期 出現症狀日期  ...   \
# 377  #378  04月08日 星期三  女  6X  臺灣    NaN  境外  2/16-3/29 印尼   3/29    4/1  ...
# 378  #379  04月08日 星期三  女  3X  臺灣  北部－桃園  本土             無    NaN    4/4  ...
# 379  #380  04月09日 星期四  男  2X  臺灣  北部－台北  本土             無    NaN    NaN  ...
# 380  #381  04月10日 星期五  女  2X  臺灣    NaN  境外            美國   3/30    4/5  ...
# 381  #382  04月10日 星期五  男  6X  臺灣    NaN  境外  2/16-3/29 印尼   3/29    NaN  ...
#
#                          症狀  疾病史       感染源  \
# 377  呼吸困難 咳嗽 發燒 全身倦怠 X光顯示肺炎  NaN    O (國外)
# 378                輕微發燒 流鼻水  NaN        未知
# 379                     無症狀  NaN  O (#322)
# 380           流鼻水 鼻塞 嗅覺異常症狀  NaN    O (國外)
# 381                     無症狀  NaN    O (國外)
#
#                                                     備註   痊癒 痊癒日期 出院日期  \
# 377                                                 探親  NaN  NaN  NaN
# 378  平時活動地以住家及周邊地區為主\n初步掌握接觸者共21人，包括個案同住家人及就醫接觸者等\n...  NaN  NaN  NaN
# ...

# %%
cov.shape
# Out:
# (382, 22)

# %%
cov.columns
# Out:
# Index(['案例', '新聞稿發布日期', '性別', '年齡', '國籍', '區域', '來源', '旅遊史', '入境臺灣日期',
#        '出現症狀日期', '就醫日期', '發現管道', '症狀', '疾病史', '感染源', '備註', '痊癒', '痊癒日期',
#        '出院日期', '疾管署新聞稿', '出院新聞稿', '案例.1'],
#       dtype='object')

# %%
cov.iloc[355]
# Out:
# 案例                  #356
# 新聞稿發布日期       04月05日 星期日
# 性別                     男
# 年齡                    6X
# 國籍                    臺灣
# 區域                 北部－新竹
# 來源                    境外
# 旅遊史         2/23-3/17 美國
# 入境臺灣日期              3/17
# 出現症狀日期               NaN
# 就醫日期        4/3通報\n4/5確診
# 發現管道                居家隔離
# 症狀                   無症狀
# 疾病史                  NaN
# 感染源               O (國外)
# 備註             工作 #343丈夫
# 痊癒                   NaN
# 痊癒日期                 NaN
# 出院日期                 NaN
# 疾管署新聞稿     新增8例確診，均為境外移入
# 出院新聞稿                NaN
# 案例.1                #356
# Name: 355, dtype: object

# %%
f=cov[cov['性別'] == '女'].shape
m=cov[cov['性別'] == '男'].shape
print(f[0],m[0])
# Out:
# 203 179

# %%
p=cov[cov['國籍'] == '中國'].shape
print(p[0])
# Out:
# 3

# %%
cov['國籍'].unique()
# Out:
# array(['臺灣', '中國', '印尼', '美國', '荷蘭', '法國', '德國', '奧地利'], dtype=object)

# %%
cov['國籍'].value_counts()
# Out:
# 臺灣     367
# 中國       3
# 法國       3
# 印尼       3
# 美國       3
# 德國       1
# 奧地利      1
# 荷蘭       1
# Name: 國籍, dtype: int64

# %%
cov.describe()
# Out:
#           案例     新聞稿發布日期   性別   年齡   國籍   區域   來源  旅遊史 入境臺灣日期 出現症狀日期  ...   \
# count    382         382  382  382  382  108  382  381    328    350  ...
# unique   382          58    2   14    8   19    2  271     46     57  ...
# top     #372  03月20日 星期五    女   2X   臺灣   北部   境外    無   3/19   3/20  ...
# freq       1          27  203  132  367   17  328   53     30     24  ...
#
#          症狀                   疾病史     感染源         備註  痊癒   痊癒日期  出院日期  \
# count   375                    14     382        369  18      4    22
# unique  273                    14      44        191   2      4    16
# top      發燒  高血壓、冠心症(血管支架+)\n抽菸史+  O (國外)  職業－學生\n就學   Y  03/29  3/29
# freq     27                     1     282         55  12      1     3
#
#                    疾管署新聞稿                出院新聞稿  案例.1
# count                 382                   27   382
# unique                 64                   25   382
# top     新增27例確診，24例境外3例本土  國內確診個案累計9人出院，其餘病況穩定  #372
# ...

# %%
cov.head(10)
# Out:
#      案例     新聞稿發布日期 性別  年齡  國籍     區域  來源                       旅遊史 入境臺灣日期  \
# 0  #001  01月21日 星期二  女  5X  臺灣  南部－高雄  境外                      中國武漢   1/20
# 1  #002  01月24日 星期五  女  5X  中國  北部－台北  境外                      中國武漢   1/21
# 2  #003  01月24日 星期五  男  5X  臺灣  南部－高雄  境外                      中國武漢   1/21
# 3  #004  01月26日 星期日  女  5X  臺灣  北部－台北  境外  1/13-15 中國武漢\n1/16-25 歐洲   1/25
# 4  #005  01月27日 星期一  女  5X  臺灣  中部－彰化  境外              2019/10 中國武漢   1/20
# 5  #006  01月28日 星期二  女  7X  中國  中部－台中  境外                      中國武漢   1/22
# 6  #007  01月28日 星期二  女  7X  中國  中部－台中  境外                      中國武漢   1/22
# 7  #008  01月28日 星期二  男  5X  臺灣  中部－彰化  本土                         無    NaN
# 8  #009  01月30日 星期四  女  4X  臺灣  中部－南投  本土                         無    NaN
# 9  #010  01月31日 星期五  男  4X  臺灣  中部－南投  境外                      中國武漢   1/12
#
#   出現症狀日期  ...              症狀  疾病史           感染源  \
# 0   1/11  ...   發燒 咳嗽 呼吸急促 肺炎  NaN        O (武漢)
# ...

# %%
cov['區域'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 352     True
# 353     True
# 354     True
# 355    False
# 356     True
# 357     True
# 358     True
# 359     True
# 360     True
# 361     True
# 362     True
# 363     True
# 364    False
# 365     True
# 366     True
# 367     True
# 368     True
# 369     True
# 370     True
# 371     True
# 372     True
# 373     True
# 374     True
# 375     True
# 376     True
# 377     True
# 378    False
# 379    False
# 380     True
# 381     True
# Name: 區域, Length: 382, dtype: bool

# %%
cov = cov.dropna(axis=1)

# %%
cov.columns
# Out:
# Index(['案例', '新聞稿發布日期', '性別', '年齡', '國籍', '來源', '感染源', '疾管署新聞稿', '案例.1'], dtype='object')

# %%
cov['年齡'].value_counts()
# Out:
# 2X       133
# 3X        86
# 5X        46
# 4X        37
# 6X        36
# 1X        20
# 7X        13
# <10        4
# 2X-6X      4
# 8X         3
# Name: 年齡, dtype: int64

# %%
cov[cov['年齡'] == '11']
cov.iloc[30]['年齡'] = '1X'

# %%
cov.to_csv("newcov.csv", encoding='utf_8_sig')

# %%
a0 = [1, 2, 3, 4, 5]
a1 = ['a', 'b', 'c', 'd', 'e']
a2 = [34232, 3532, 543, 4542, 123]
#dict[list] -> dataframe
d = {'a0':a0, 'a1':a1, 'a2':a2}

# %%
d = pd.DataFrame(d)

# %%
d.to_csv("d.csv", encoding='utf_8_sig')
